# %%
import pandas as pd
import re
# file: data_demHawaii.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaii = ["Hawaii"]
category = ['Demographics']
df = df[df['Location'].isin(lHawaii)]
df = df[df['Category'].isin(category)]
df_demographics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['demographicsHawaii'] = df_demographics
df_demographics = re.sub(r'\\', '', df[['demographicsHawaii']].to_json(orient='records', indent=4))
print(df_demographics)
# Out:
# [
#     {
#         "demographicsHawaii":{
#             "Indicator":"Percent of children in immigrant families",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"28.2%",
#             "Previous":"28.6%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9672-of-children-in-immigrant-families?loc=13&loct=2#detailed/2/any/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18904"
#         }
#     },
#     {
#         "demographicsHawaii":{
#             "Indicator":"Percent of families with children",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"36.1%",
#             "Previous":"36.4%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9282-of-families-with-children?loc=13&loct=2#detailed/2/any/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18366"
#         }
#     },
#     {
#         "demographicsHawaii":{
#             "Indicator":"Population of children under 18",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"293,607",
#             "Previous":"297,119",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9409-population-of-children-under-age-18?loc=13&loct=2#detailed/2/any/false/2545,1095,2048,574,1729,37,871,870,573,869/6274/18540"
#         }
#     },
#     {
#         "demographicsHawaii":{
#             "Indicator":"Percent of families with children that have young children",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"40.8%",
#             "Previous":"41.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9286-of-families-with-children-that-have-young-children?loc=13&loct=2#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18369"
#         }
#     }
# ]

# %%
# file: data_demHawaiico.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaiico = ["Hawaii County"]
category = ['Demographics']
df = df[df['Location'].isin(lHawaiico)]
df = df[df['Category'].isin(category)]
df_demographics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['demographicsHawaiico'] = df_demographics
df_demographics = re.sub(r'\\', '', df[['demographicsHawaiico']].to_json(orient='records', indent=4))
print(df_demographics)
# Out:
# [
#     {
#         "demographicsHawaiico":{
#             "Indicator":"Percent of children in immigrant families",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"20.2%",
#             "Previous":"21.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9672-of-children-in-immigrant-families?loc=13&loct=2#detailed/5/7267/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18904"
#         }
#     },
#     {
#         "demographicsHawaiico":{
#             "Indicator":"Percent of families with children",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"34.5%",
#             "Previous":"35.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9282-of-families-with-children?loc=13&loct=2#detailed/5/7267/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18366"
#         }
#     },
#     {
#         "demographicsHawaiico":{
#             "Indicator":"Population of children under 18",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"42,623",
#             "Previous":"42,762",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9409-population-of-children-under-age-18?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/6274/18540"
#         }
#     },
#     {
#         "demographicsHawaiico":{
#             "Indicator":"Percent of families with children that have young children",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"36.6%",
#             "Previous":"38.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9286-of-families-with-children-that-have-young-children?loc=13&loct=2#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18369"
#         }
#     }
# ]

# %%
# file: data_demHonolulu.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHonolulu = ["C&C Honolulu"]
category = ['Demographics']
df = df[df['Location'].isin(lHonolulu)]
df = df[df['Category'].isin(category)]
df_demographics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['demographicsHonolulu'] = df_demographics
df_demographics = re.sub(r'\\', '', df[['demographicsHonolulu']].to_json(orient='records', indent=4))
print(df_demographics)
# Out:
# [
#     {
#         "demographicsHonolulu":{
#             "Indicator":"Percent of children in immigrant families",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"29.9%",
#             "Previous":"30.0%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9672-of-children-in-immigrant-families?loc=13&loct=2#detailed/5/7266/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18904"
#         }
#     },
#     {
#         "demographicsHonolulu":{
#             "Indicator":"Percent of families with children",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"36.7%",
#             "Previous":"37.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9282-of-families-with-children?loc=13&loct=2#detailed/5/7266/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18366"
#         }
#     },
#     {
#         "demographicsHonolulu":{
#             "Indicator":"Population of children under 18",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"201,494",
#             "Previous":"204,341",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9409-population-of-children-under-age-18?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/6274/18540"
#         }
#     },
#     {
#         "demographicsHonolulu":{
#             "Indicator":"Percent of families with children that have young children",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"42.6%",
#             "Previous":"42.9%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9286-of-families-with-children-that-have-young-children?loc=13&loct=2#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18369"
#         }
#     }
# ]

# %%
# file: data_demKauai.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lKauai = ["Kauai County"]
category = ['Demographics']
df = df[df['Location'].isin(lKauai)]
df = df[df['Category'].isin(category)]
df_demographics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['demographicsKauai'] = df_demographics
df_demographics = re.sub(r'\\', '', df[['demographicsKauai']].to_json(orient='records', indent=4))
print(df_demographics)
# Out:
# [
#     {
#         "demographicsKauai":{
#             "Indicator":"Percent of children in immigrant families",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"18.0%",
#             "Previous":"20.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9672-of-children-in-immigrant-families?loc=13&loct=2#detailed/5/7268/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18904"
#         }
#     },
#     {
#         "demographicsKauai":{
#             "Indicator":"Percent of families with children",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"31.2%",
#             "Previous":"32.4%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9282-of-families-with-children?loc=13&loct=2#detailed/5/7268/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18366"
#         }
#     },
#     {
#         "demographicsKauai":{
#             "Indicator":"Population of children under 18",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"15,577",
#             "Previous":"15,657",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9409-population-of-children-under-age-18?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/6274/18540"
#         }
#     },
#     {
#         "demographicsKauai":{
#             "Indicator":"Percent of families with children that have young children",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"32.3%",
#             "Previous":"38.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9286-of-families-with-children-that-have-young-children?loc=13&loct=2#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18369"
#         }
#     }
# ]

# %%
# file: data_demMaui.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lMaui = ["Maui County"]
category = ['Demographics']
df = df[df['Location'].isin(lMaui)]
df = df[df['Category'].isin(category)]
df_demographics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['demographicsMaui'] = df_demographics
df_demographics = re.sub(r'\\', '', df[['demographicsMaui']].to_json(orient='records', indent=4))
print(df_demographics)
# Out:
# [
#     {
#         "demographicsMaui":{
#             "Indicator":"Percent of children in immigrant families",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"32.4%",
#             "Previous":"33.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9672-of-children-in-immigrant-families?loc=13&loct=2#detailed/5/7269/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18904"
#         }
#     },
#     {
#         "demographicsMaui":{
#             "Indicator":"Percent of families with children",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"36.8%",
#             "Previous":"36.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9282-of-families-with-children?loc=13&loct=2#detailed/5/7269/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18366"
#         }
#     },
#     {
#         "demographicsMaui":{
#             "Indicator":"Population of children under 18",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"33,913",
#             "Previous":"34,359",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9409-population-of-children-under-age-18?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/6274/18540"
#         }
#     },
#     {
#         "demographicsMaui":{
#             "Indicator":"Percent of families with children that have young children",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"38.2%",
#             "Previous":"38.4%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9286-of-families-with-children-that-have-young-children?loc=13&loct=2#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18369"
#         }
#     }
# ]

# %%
# file: data_edHawaii.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaii = ["Hawaii"]
category = ['Education']
df = df[df['Location'].isin(lHawaii)]
df = df[df['Category'].isin(category)]
df_education = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['educationHawaii'] = df_education
df_education = re.sub(r'\\', '', df[['educationHawaii']].to_json(orient='records', indent=4))
print(df_education)
# Out:
# [
#     {
#         "educationHawaii":{
#             "Indicator":"High school seniors graduating with a diploma",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"96.3%",
#             "Previous":"94.4%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4874-high-school-seniors-graduating-with-a-diploma?loc=13&loct=2#detailed/2/any/true/2545,1095,2048,574,1729,37,871,870,573,869/any/11258"
#         }
#     },
#     {
#         "educationHawaii":{
#             "Indicator":"Percent of K-12 students in special education",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.7%",
#             "Previous":"10.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9684-of-k-12-students-in-special-education?loc=13&loct=2#detailed/2/any/true/2545,1095,2048,574,1729,37,871,870,573,869/any/18923"
#         }
#     },
#     {
#         "educationHawaii":{
#             "Indicator":"Percent of students who are English language learners",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.5%",
#             "Previous":"10.1%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9685-of-students-who-are-english-language-learners?loc=13&loct=2#detailed/2/any/true/2545,1095,2048,574,1729,37,871,870,573,869/any/18924"
#         }
#     },
#     {
#         "educationHawaii":{
#             "Indicator":"On-time graduation",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"85.8%",
#             "Previous":"85.9%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4591-on-time-graduation?loc=13&loct=2#detailed/2/any/false/2545,1095,2048,574,1729,37,871,870,573,869/any/10606"
#         }
#     }
# ]

# %%
# file: data_edHawaiico.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaiico = ["Hawaii County"]
category = ['Education']
df = df[df['Location'].isin(lHawaiico)]
df = df[df['Category'].isin(category)]
df_education = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['educationHawaiico'] = df_education
df_education = re.sub(r'\\', '', df[['educationHawaiico']].to_json(orient='records', indent=4))
print(df_education)
# Out:
# [
#     {
#         "educationHawaiico":{
#             "Indicator":"High school seniors graduating with a diploma",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"92.5%",
#             "Previous":"90.4%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4874-high-school-seniors-graduating-with-a-diploma?loc=13&loct=2#detailed/5/7267/true/2545,1095,2048,574,1729,37,871,870,573,869/any/11258"
#         }
#     },
#     {
#         "educationHawaiico":{
#             "Indicator":"Percent of K-12 students in special education",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"11.7%",
#             "Previous":"11.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9684-of-k-12-students-in-special-education?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18923"
#         }
#     },
#     {
#         "educationHawaiico":{
#             "Indicator":"Percent of students who are English language learners",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"11.4%",
#             "Previous":"10.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9685-of-students-who-are-english-language-learners?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18924"
#         }
#     },
#     {
#         "educationHawaiico":{
#             "Indicator":"On-time graduation",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"83.2%",
#             "Previous":"82.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4591-on-time-graduation?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/any/10606"
#         }
#     }
# ]

# %%
# file: data_edHonolulu.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHonolulu = ["C&C Honolulu"]
category = ['Education']
df = df[df['Location'].isin(lHonolulu)]
df = df[df['Category'].isin(category)]
df_education = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['educationHonolulu'] = df_education
df_education = re.sub(r'\\', '', df[['educationHonolulu']].to_json(orient='records', indent=4))
print(df_education)
# Out:
# [
#     {
#         "educationHonolulu":{
#             "Indicator":"High school seniors graduating with a diploma",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"97.7%",
#             "Previous":"94.9%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4874-high-school-seniors-graduating-with-a-diploma?loc=13&loct=2#detailed/5/7266/true/2545,1095,2048,574,1729,37,871,870,573,869/any/11258"
#         }
#     },
#     {
#         "educationHonolulu":{
#             "Indicator":"Percent of K-12 students in special education",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.7%",
#             "Previous":"10.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9684-of-k-12-students-in-special-education?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18923"
#         }
#     },
#     {
#         "educationHonolulu":{
#             "Indicator":"Percent of students who are English language learners",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.6%",
#             "Previous":"10.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9685-of-students-who-are-english-language-learners?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18924"
#         }
#     },
#     {
#         "educationHonolulu":{
#             "Indicator":"On-time graduation",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"86.8%",
#             "Previous":"86.8%",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/4591-on-time-graduation?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/any/10606"
#         }
#     }
# ]

# %%
# file: data_edKauai.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lKauai = ["Kauai County"]
category = ['Education']
df = df[df['Location'].isin(lKauai)]
df = df[df['Category'].isin(category)]
df_education = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['educationKauai'] = df_education
df_education = re.sub(r'\\', '', df[['educationKauai']].to_json(orient='records', indent=4))
print(df_education)
# Out:
# [
#     {
#         "educationKauai":{
#             "Indicator":"High school seniors graduating with a diploma",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"96.2%",
#             "Previous":"97.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4874-high-school-seniors-graduating-with-a-diploma?loc=13&loct=2#detailed/5/7268/true/2545,1095,2048,574,1729,37,871,870,573,869/any/11258"
#         }
#     },
#     {
#         "educationKauai":{
#             "Indicator":"Percent of K-12 students in special education",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"9.9%",
#             "Previous":"9.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9684-of-k-12-students-in-special-education?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18923"
#         }
#     },
#     {
#         "educationKauai":{
#             "Indicator":"Percent of students who are English language learners",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"7.9%",
#             "Previous":"7.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9685-of-students-who-are-english-language-learners?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18924"
#         }
#     },
#     {
#         "educationKauai":{
#             "Indicator":"On-time graduation",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"89.6%",
#             "Previous":"92.8%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4591-on-time-graduation?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/any/10606"
#         }
#     }
# ]

# %%
# file: data_edMaui.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lMaui = ["Maui County"]
category = ['Education']
df = df[df['Location'].isin(lMaui)]
df = df[df['Category'].isin(category)]
df_education = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['educationMaui'] = df_education
df_education = re.sub(r'\\', '', df[['educationMaui']].to_json(orient='records', indent=4))
print(df_education)
# Out:
# [
#     {
#         "educationMaui":{
#             "Indicator":"High school seniors graduating with a diploma",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"94.1%",
#             "Previous":"95.7%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4874-high-school-seniors-graduating-with-a-diploma?loc=13&loct=2#detailed/5/7269/true/2545,1095,2048,574,1729,37,871,870,573,869/any/11258"
#         }
#     },
#     {
#         "educationMaui":{
#             "Indicator":"Percent of K-12 students in special education",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.7%",
#             "Previous":"10.6%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9684-of-k-12-students-in-special-education?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18923"
#         }
#     },
#     {
#         "educationMaui":{
#             "Indicator":"Percent of students who are English language learners",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"10.9%",
#             "Previous":"10.6%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9685-of-students-who-are-english-language-learners?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/any/18924"
#         }
#     },
#     {
#         "educationMaui":{
#             "Indicator":"On-time graduation",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"81.9%",
#             "Previous":"81.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4591-on-time-graduation?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/any/10606"
#         }
#     }
# ]

# %%
# file: data_ecHawaii.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaii = ["Hawaii"]
category = ['Economic']
df = df[df['Location'].isin(lHawaii)]
df = df[df['Category'].isin(category)]
df_economics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['economicsHawaii'] = df_economics
df_economics = re.sub(r'\\', '', df[['economicsHawaii']].to_json(orient='records', indent=4))
print(df_economics)
# Out:
# [
#     {
#         "economicsHawaii":{
#             "Indicator":"Teens ages 16-19 not attending school/nnot working",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"8.5%",
#             "Previous":"8.7%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9792-teens-ages-16-to-19-not-attending-school-not-working?loc=13&loct=2#detailed/2/any/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19067"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Children receiving public assistance",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"25.8%",
#             "Previous":"24.9%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9777-children-receiving-public-assistance?loc=13&loct=5#detailed/2/any/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19050"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Percent children with no parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"7.4%",
#             "Previous":"7.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9897-of-children-with-no-parents-in-workforce?loc=13&loct=2#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/19227"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Children under 18 in poverty",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"12.4%",
#             "Previous":"12.0%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9527-children-under-age-18-in-poverty?loc=13&loct=2#detailed/2/any/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18699"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Households with a housing cost burden (owner)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"30.5%",
#             "Previous":"30.1%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3500|6273/19562"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Households with a housing cost burden (renter)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"51.9%",
#             "Previous":"51.4%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3501|6273/19562"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Percent of young children with all parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"67.4%",
#             "Previous":"66.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9899-of-young-children-with-all-parents-in-workforce?loc=13&loct=2#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/any/19229"
#         }
#     },
#     {
#         "economicsHawaii":{
#             "Indicator":"Children under 18 in low-income families",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"28.1%",
#             "Previous":"28.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9531-children-under-age-18-in-low-income-families?loc=13&loct=5#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18703"
#         }
#     }
# ]

# %%
# file: data_ecHawaiico.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaiico = ["Hawaii County"]
category = ['Economic']
df = df[df['Location'].isin(lHawaiico)]
df = df[df['Category'].isin(category)]
df_economics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['economicsHawaiico'] = df_economics
df_economics = re.sub(r'\\', '', df[['economicsHawaiico']].to_json(orient='records', indent=4))
print(df_economics)
# Out:
# [
#     {
#         "economicsHawaiico":{
#             "Indicator":"Teens ages 16-19 not attending school/nnot working",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"11.0%",
#             "Previous":"9.7%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9792-teens-ages-16-to-19-not-attending-school-not-working?loc=13&loct=2#detailed/5/7267/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19067"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Children receiving public assistance",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"39.3%",
#             "Previous":"38.9%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9777-children-receiving-public-assistance?loc=13&loct=5#detailed/5/7267/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19050"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Percent children with no parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"9.4%",
#             "Previous":"10.0%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9897-of-children-with-no-parents-in-workforce?loc=13&loct=2#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/19227"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Children under 18 in poverty",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"19.2%",
#             "Previous":"18.3%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9527-children-under-age-18-in-poverty?loc=13&loct=2#detailed/5/7267/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18699"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Households with a housing cost burden (owner)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"27.1%",
#             "Previous":"26.4%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3500|6273/19562"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Households with a housing cost burden (renter)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"43.9%",
#             "Previous":"43.9%",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3501|6273/19562"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Percent of young children with all parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"72.5%",
#             "Previous":"70.6%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9899-of-young-children-with-all-parents-in-workforce?loc=13&loct=2#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/any/19229"
#         }
#     },
#     {
#         "economicsHawaiico":{
#             "Indicator":"Children under 18 in low-income families",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"38.7%",
#             "Previous":"40.0%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9531-children-under-age-18-in-low-income-families?loc=13&loct=5#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18703"
#         }
#     }
# ]

# %%
# file: data_ecHonolulu.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHonolulu = ["C&C Honolulu"]
category = ['Economic']
df = df[df['Location'].isin(lHonolulu)]
df = df[df['Category'].isin(category)]
df_economics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['economicsHonolulu'] = df_economics
df_economics = re.sub(r'\\', '', df[['economicsHonolulu']].to_json(orient='records', indent=4))
print(df_economics)
# Out:
# [
#     {
#         "economicsHonolulu":{
#             "Indicator":"Teens ages 16-19 not attending school/nnot working",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"8.1%",
#             "Previous":"8.1%",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/9792-teens-ages-16-to-19-not-attending-school-not-working?loc=13&loct=2#detailed/5/7266/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19067"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Children receiving public assistance",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"23.5%",
#             "Previous":"22.7%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9777-children-receiving-public-assistance?loc=13&loct=5#detailed/5/7266/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19050"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Percent children with no parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"7.2%",
#             "Previous":"7.2%",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/9897-of-children-with-no-parents-in-workforce?loc=13&loct=2#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/19227"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Children under 18 in poverty",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"11.4%",
#             "Previous":"11.0%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9527-children-under-age-18-in-poverty?loc=13&loct=2#detailed/5/7266/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18699"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Households with a housing cost burden (owner)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"31.0%",
#             "Previous":"30.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3500|6273/19562"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Households with a housing cost burden (renter)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"53.9%",
#             "Previous":"53.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3501|6273/19562"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Percent of young children with all parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"64.9%",
#             "Previous":"63.9%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9899-of-young-children-with-all-parents-in-workforce?loc=13&loct=2#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/any/19229"
#         }
#     },
#     {
#         "economicsHonolulu":{
#             "Indicator":"Children under 18 in low-income families",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"25.7%",
#             "Previous":"26.4%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9531-children-under-age-18-in-low-income-families?loc=13&loct=5#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18703"
#         }
#     }
# ]

# %%
# file: data_ecKauai.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lKauai = ["Kauai County"]
category = ['Economic']
df = df[df['Location'].isin(lKauai)]
df = df[df['Category'].isin(category)]
df_economics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['economicsKauai'] = df_economics
df_economics = re.sub(r'\\', '', df[['economicsKauai']].to_json(orient='records', indent=4))
print(df_economics)
# Out:
# [
#     {
#         "economicsKauai":{
#             "Indicator":"Teens ages 16-19 not attending school/nnot working",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"7.1%",
#             "Previous":"8.9%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9792-teens-ages-16-to-19-not-attending-school-not-working?loc=13&loct=2#detailed/5/7268/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19067"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Children receiving public assistance",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"24.7%",
#             "Previous":"22.6%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9777-children-receiving-public-assistance?loc=13&loct=5#detailed/5/7268/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19050"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Percent children with no parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"7.1%",
#             "Previous":"5.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9897-of-children-with-no-parents-in-workforce?loc=13&loct=2#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/19227"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Children under 18 in poverty",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"10.6%",
#             "Previous":"11.6%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9527-children-under-age-18-in-poverty?loc=13&loct=2#detailed/5/7268/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18699"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Households with a housing cost burden (owner)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"30.9%",
#             "Previous":"30.7%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3500|6273/19562"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Households with a housing cost burden (renter)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"44.1%",
#             "Previous":"41.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3501|6273/19562"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Percent of young children with all parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"71.0%",
#             "Previous":"69.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9899-of-young-children-with-all-parents-in-workforce?loc=13&loct=2#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/any/19229"
#         }
#     },
#     {
#         "economicsKauai":{
#             "Indicator":"Children under 18 in low-income families",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"31.9%",
#             "Previous":"30.7%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9531-children-under-age-18-in-low-income-families?loc=13&loct=5#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18703"
#         }
#     }
# ]

# %%
# file: data_ecMaui.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lMaui = ["Maui County"]
category = ['Economic']
df = df[df['Location'].isin(lMaui)]
df = df[df['Category'].isin(category)]
df_economics = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['economicsMaui'] = df_economics
df_economics = re.sub(r'\\', '', df[['economicsMaui']].to_json(orient='records', indent=4))
print(df_economics)
# Out:
# [
#     {
#         "economicsMaui":{
#             "Indicator":"Teens ages 16-19 not attending school/nnot working",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"8.8%",
#             "Previous":"10.9%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9792-teens-ages-16-to-19-not-attending-school-not-working?loc=13&loct=2#detailed/5/7269/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19067"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Children receiving public assistance",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"23.4%",
#             "Previous":"21.7%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9777-children-receiving-public-assistance?loc=13&loct=5#detailed/5/7269/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/19050"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Percent children with no parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"6.1%",
#             "Previous":"6.8%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9897-of-children-with-no-parents-in-workforce?loc=13&loct=2#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/19227"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Children under 18 in poverty",
#             "CurrentYear":"2018-2022",
#             "PreviousYear":"2017-2021",
#             "Current":"10.9%",
#             "Previous":"10.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9527-children-under-age-18-in-poverty?loc=13&loct=2#detailed/5/7269/false/2543,2454,2026,1983,1692,1691,1607,1572,1485,1376/6273/18699"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Households with a housing cost burden (owner)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"32.1%",
#             "Previous":"32.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3500|6273/19562"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Households with a housing cost burden (renter)",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"48.7%",
#             "Previous":"47.0%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10133-households-with-a-housing-cost-burden?loc=13&loct=2#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/3501|6273/19562"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Percent of young children with all parents in workforce",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"76.7%",
#             "Previous":"76.7%",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/9899-of-young-children-with-all-parents-in-workforce?loc=13&loct=2#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/any/19229"
#         }
#     },
#     {
#         "economicsMaui":{
#             "Indicator":"Children under 18 in low-income families",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"27.3%",
#             "Previous":"26.1%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/9531-children-under-age-18-in-low-income-families?loc=13&loct=5#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691,1607,1572,1485/6273/18703"
#         }
#     }
# ]

# %%
# file: data_heHawaii.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaii = ["Hawaii"]
category = ['Health']
df = df[df['Location'].isin(lHawaii)]
df = df[df['Category'].isin(category)]
df_health = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['healthHawaii'] = df_health
df_health = re.sub(r'\\', '', df[['healthHawaii']].to_json(orient='records', indent=4))
print(df_health)
# Out:
# [
#     {
#         "healthHawaii":{
#             "Indicator":"Birth to resident teens",
#             "CurrentYear":"2022 rate per 1,000",
#             "PreviousYear":"2021",
#             "Current":"11.6",
#             "Previous":"12.4",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9554-births-to-resident-teens-ages-15-to-19?loc=13&loct=5#detailed/2/any/false/2545,1095,2048,574,1729,37,871,870,573,869/6445/22056"
#         }
#     },
#     {
#         "healthHawaii":{
#             "Indicator":"Children with health insurance",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"97.0%",
#             "Previous":"97.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10406-of-children-with-health-insurance?loc=13&loct=5#detailed/2/any/false/2606,2543,2454,2026,1983,1692,1691/6273/20092"
#         }
#     },
#     {
#         "healthHawaii":{
#             "Indicator":"Child abuse and neglect (birth to age 17)",
#             "CurrentYear":"2023 rate per 1,000",
#             "PreviousYear":"2022",
#             "Current":"2.5",
#             "Previous":"3.9",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/11979-child-abuse-and-neglect-birth-to-age-17?loc=13&loct=2#detailed/2/any/true/2545,1095,2048,574/6445/23402"
#         }
#     },
#     {
#         "healthHawaii":{
#             "Indicator":"Early prenatal care",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"55.6%",
#             "Previous":"59.0%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4533-early-prenatal-care?loc=13&loct=2#detailed/2/any/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/10358"
#         }
#     },
#     {
#         "healthHawaii":{
#             "Indicator":"Low birth weight",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"8.6%",
#             "Previous":"8.3%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10282-low-birth-weight?loc=13&loct=2#detailed/2/any/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/19910"
#         }
#     }
# ]

# %%
# file: data_heHawaiico.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHawaiico = ["Hawaii County"]
category = ['Health']
df = df[df['Location'].isin(lHawaiico)]
df = df[df['Category'].isin(category)]
df_health = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['healthHawaiico'] = df_health
df_health = re.sub(r'\\', '', df[['healthHawaiico']].to_json(orient='records', indent=4))
print(df_health)
# Out:
# [
#     {
#         "healthHawaiico":{
#             "Indicator":"Birth to resident teens",
#             "CurrentYear":"2022 rate per 1,000",
#             "PreviousYear":"2021",
#             "Current":"15.8",
#             "Previous":"16.4",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9554-births-to-resident-teens-ages-15-to-19?loc=13&loct=5#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/6445/22056"
#         }
#     },
#     {
#         "healthHawaiico":{
#             "Indicator":"Children with health insurance",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"96.8%",
#             "Previous":"97.1%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10406-of-children-with-health-insurance?loc=13&loct=5#detailed/5/7267/false/2606,2543,2454,2026,1983,1692,1691/6273/20092"
#         }
#     },
#     {
#         "healthHawaiico":{
#             "Indicator":"Child abuse and neglect (birth to age 17)",
#             "CurrentYear":"2023 rate per 1,000",
#             "PreviousYear":"2022",
#             "Current":"5.4",
#             "Previous":"9.3",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/11979-child-abuse-and-neglect-birth-to-age-17?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574/6445/23402"
#         }
#     },
#     {
#         "healthHawaiico":{
#             "Indicator":"Early prenatal care",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"45.9%",
#             "Previous":"45.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/4533-early-prenatal-care?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/10358"
#         }
#     },
#     {
#         "healthHawaiico":{
#             "Indicator":"Low birth weight",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"8.6%",
#             "Previous":"8.7%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/10282-low-birth-weight?loc=13&loct=2#detailed/5/7267/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/19910"
#         }
#     }
# ]

# %%
# file: data_heHonolulu.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lHonolulu = ["C&C Honolulu"]
category = ['Health']
df = df[df['Location'].isin(lHonolulu)]
df = df[df['Category'].isin(category)]
df_health = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['healthHonolulu'] = df_health
df_health = re.sub(r'\\', '', df[['healthHonolulu']].to_json(orient='records', indent=4))
print(df_health)
# Out:
# [
#     {
#         "healthHonolulu":{
#             "Indicator":"Birth to resident teens",
#             "CurrentYear":"2022 rate per 1,000",
#             "PreviousYear":"2021",
#             "Current":"10.6",
#             "Previous":"11.3",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9554-births-to-resident-teens-ages-15-to-19?loc=13&loct=5#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/6445/22056"
#         }
#     },
#     {
#         "healthHonolulu":{
#             "Indicator":"Children with health insurance",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"97.4%",
#             "Previous":"97.5%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10406-of-children-with-health-insurance?loc=13&loct=5#detailed/5/7266/false/2606,2543,2454,2026,1983,1692,1691/6273/20092"
#         }
#     },
#     {
#         "healthHonolulu":{
#             "Indicator":"Child abuse and neglect (birth to age 17)",
#             "CurrentYear":"2023 rate per 1,000",
#             "PreviousYear":"2022",
#             "Current":"1.8",
#             "Previous":"2.6",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/11979-child-abuse-and-neglect-birth-to-age-17?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574/6445/23402"
#         }
#     },
#     {
#         "healthHonolulu":{
#             "Indicator":"Early prenatal care",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"56.7%",
#             "Previous":"61.1%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4533-early-prenatal-care?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/10358"
#         }
#     },
#     {
#         "healthHonolulu":{
#             "Indicator":"Low birth weight",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"8.7%",
#             "Previous":"8.4%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10282-low-birth-weight?loc=13&loct=2#detailed/5/7266/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/19910"
#         }
#     }
# ]

# %%
# file: data_heKauai.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lKauai = ["Kauai County"]
category = ['Health']
df = df[df['Location'].isin(lKauai)]
df = df[df['Category'].isin(category)]
df_health = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['healthKauai'] = df_health
df_health = re.sub(r'\\', '', df[['healthKauai']].to_json(orient='records', indent=4))
print(df_health)
# Out:
# [
#     {
#         "healthKauai":{
#             "Indicator":"Birth to resident teens",
#             "CurrentYear":"2022 rate per 1,000",
#             "PreviousYear":"2021",
#             "Current":"12.1",
#             "Previous":"12.1",
#             "Change":"flat",
#             "Source":"https://datacenter.aecf.org/data/tables/9554-births-to-resident-teens-ages-15-to-19?loc=13&loct=5#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/6445/22056"
#         }
#     },
#     {
#         "healthKauai":{
#             "Indicator":"Children with health insurance",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"96.4%",
#             "Previous":"95.8%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10406-of-children-with-health-insurance?loc=13&loct=5#detailed/5/7268/false/2606,2543,2454,2026,1983,1692,1691/6273/20092"
#         }
#     },
#     {
#         "healthKauai":{
#             "Indicator":"Child abuse and neglect (birth to age 17)",
#             "CurrentYear":"2023 rate per 1,000",
#             "PreviousYear":"2022",
#             "Current":"4.0",
#             "Previous":"6.1",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/11979-child-abuse-and-neglect-birth-to-age-17?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574/6445/23402"
#         }
#     },
#     {
#         "healthKauai":{
#             "Indicator":"Early prenatal care",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"74.5%",
#             "Previous":"74.9%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4533-early-prenatal-care?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/10358"
#         }
#     },
#     {
#         "healthKauai":{
#             "Indicator":"Low birth weight",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"7.4%",
#             "Previous":"6.2%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10282-low-birth-weight?loc=13&loct=2#detailed/5/7268/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/19910"
#         }
#     }
# ]

# %%
# file: data_heMaui.json
df = pd.read_csv('https://raw.githubusercontent.com/kathanner/hcan/main/kids_count_data.csv')
lMaui = ["Maui County"]
category = ['Health']
df = df[df['Location'].isin(lMaui)]
df = df[df['Category'].isin(category)]
df_health = df[["Indicator","CurrentYear","PreviousYear","Current","Previous","Change","Source"]].to_dict('records')
df['healthMaui'] = df_health
df_health = re.sub(r'\\', '', df[['healthMaui']].to_json(orient='records', indent=4))
print(df_health)
# Out:
# [
#     {
#         "healthMaui":{
#             "Indicator":"Birth to resident teens",
#             "CurrentYear":"2022 rate per 1,000",
#             "PreviousYear":"2021",
#             "Current":"11.8",
#             "Previous":"14.4",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/9554-births-to-resident-teens-ages-15-to-19?loc=13&loct=5#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/6445/22056"
#         }
#     },
#     {
#         "healthMaui":{
#             "Indicator":"Children with health insurance",
#             "CurrentYear":"2019-2023",
#             "PreviousYear":"2018-2022",
#             "Current":"95.7%",
#             "Previous":"95.9%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10406-of-children-with-health-insurance?loc=13&loct=5#detailed/5/7269/false/2606,2543,2454,2026,1983,1692,1691/6273/20092"
#         }
#     },
#     {
#         "healthMaui":{
#             "Indicator":"Child abuse and neglect (birth to age 17)",
#             "CurrentYear":"2023 rate per 1,000",
#             "PreviousYear":"2022",
#             "Current":"2.7",
#             "Previous":"3.9",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/11979-child-abuse-and-neglect-birth-to-age-17?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574/6445/23402"
#         }
#     },
#     {
#         "healthMaui":{
#             "Indicator":"Early prenatal care",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"52.0%",
#             "Previous":"54.5%",
#             "Change":"down",
#             "Source":"https://datacenter.aecf.org/data/tables/4533-early-prenatal-care?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/10358"
#         }
#     },
#     {
#         "healthMaui":{
#             "Indicator":"Low birth weight",
#             "CurrentYear":"2023",
#             "PreviousYear":"2022",
#             "Current":"8.4%",
#             "Previous":"8.3%",
#             "Change":"up",
#             "Source":"https://datacenter.aecf.org/data/tables/10282-low-birth-weight?loc=13&loct=2#detailed/5/7269/false/2545,1095,2048,574,1729,37,871,870,573,869/6273/19910"
#         }
#     }
# ]
